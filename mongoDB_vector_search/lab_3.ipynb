# %% [markdown]
# Vector Search using vCore-based Azure Cosmos DB for MongoDB
#
# This notebook demonstrates using an Azure OpenAI embedding model to vectorize documents already stored in Azure Cosmos DB API for MongoDB, storing the embedding vectors and the creation of a vector index. Lastly, the notebook will demonstrate how to query the vector index to find similar documents.
#
# Make sure that the lab in load_data was ran

# %%
! pip install pymongo
! pip install openai
! pip install python-dotenv
! pip install tenacity
# Out:
# Requirement already satisfied: pymongo in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from pymongo) (2.6.1)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openai in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (1.35.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.7.4)
# Requirement already satisfied: sniffio in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)
# Requirement already satisfied: colorama in c:\users\amanb\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tenacity in c:\users\amanb\appdata\local\programs\python\python312\lib\site-packages (8.4.2)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pymongo
import time
import json
from openai import AzureOpenAI
from dotenv import load_dotenv
from tenacity import retry, wait_random_exponential, stop_after_attempt

# %% [markdown]
# Load settings and establish connectivity to database and openAI

# %%
load_dotenv()
CONNECTION_STRING = os.environ.get("DB_CONNECTION_STRING")
client = pymongo.MongoClient(CONNECTION_STRING)
# Create database to hold cosmic works data
# MongoDB will create the database if it does not exist
db = client.cosmic_works

EMBEDDINGS_DEPLOYMENT_NAME = "embeddings"
COMPLETIONS_DEPLOYMENT_NAME = "completions"
AOAI_ENDPOINT = os.environ.get("AOAI_ENDPOINT")
AOAI_KEY = os.environ.get("AOAI_KEY")
AOAI_API_VERSION = "2023-05-15"

ai_client = AzureOpenAI(
    azure_endpoint = AOAI_ENDPOINT,
    api_version = AOAI_API_VERSION,
    api_key = AOAI_KEY
    )
# Out:
# C:\Users\amanb\AppData\Local\Temp\ipykernel_14080\3342752961.py:3: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(CONNECTION_STRING)

# %% [markdown]
# Vectorize and store the embeddings in each document
#
# The process of creating a vector embedding field on each document only needs to be done once. However, if a document changes, the vector embedding field will need to be updated with an updated vector.

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(3))
def generate_embeddings(text: str):
    '''
    Generate embeddings from string of text using the deployed Azure OpenAI API embeddings model.
    This will be used to vectorize document data and incoming user messages for a similarity search with
    the vector index.
    '''
    response = ai_client.embeddings.create(input=text, model=EMBEDDINGS_DEPLOYMENT_NAME)
    embeddings = response.data[0].embedding
    time.sleep(0.5) # rest period to avoid rate limiting on AOAI
    return embeddings

# %%
# demonstrate embeddings generation using a test string
test = "hello, world"
print(generate_embeddings(test))
# Out:
# [-0.016903093, -0.0068888566, -0.027763786, -0.046490017, -0.011016962, 0.01019655, -0.014064207, -0.004762948, -0.018856455, -0.028388862, 0.029092072, 0.01996336, -0.021812543, -0.006263781, 0.009525896, 0.006566552, 0.017410967, -0.0143507, 0.011863419, 0.018804366, -0.0124950055, -1.7002898e-05, 0.009206846, -0.010281196, -0.009695187, -0.016551487, 0.006986525, -0.016759846, 0.024560273, -0.03815567, 0.00072762737, 0.0034574508, -0.016043615, -0.006322382, 0.01116672, -0.011935042, 0.0009498223, -0.027789831, 0.029534834, -0.011290433, 0.0023961242, -0.007116749, 0.0041606613, -0.013725624, -0.03263417, 0.0127554545, 0.008718506, -0.015079955, 0.0042420514, 0.02260691, 0.021773476, 0.001420257, -0.024443071, -0.0018866222, -0.013289373, 0.008751062, -0.035473056, 0.014780439, 0.020145673, -0.020666571, 0.01601757, 0.0037309215, -0.025471842, 0.012091311, -0.009988192, 0.010235617, 0.016199883, 0.008588281, -0.019351307, 0.014585103, 0.021005154, 0.019051792, -0.005482436, -0.0077613587, 0.02185161, -0.0006901879, -0.012553607, -0.00027102898, -0.0015293197, -0.00058315997, 0.038103584, -0.03620231, -0.0034183837, 0.011049518, 0.014624171, 0.015652942, -0.0031514242, 0.017697461, -0.015613874, -0.015145067, -0.004538311, 0.002150326, 0.018713208, 0.014077229, -0.029534834, 0.013855848, 0.008770595, 0.02703453, 0.003045617, -0.041671723, -0.017189587, -0.007116749, -0.0048703826, -0.010046792, -0.024586316, -0.0124950055, -0.0006275176, 0.003512796, 0.023218963, 0.0076246234, -0.01472835, 0.021916723, -0.0062995926, -0.0241696, -0.008718506, -0.00599031, -0.016030591, -0.004209495, -0.011902486, -0.015236224, 0.015718054, 0.02459934, 0.01704634, -0.022893403, 0.0115704145, 0.0024010076, -0.04552636, -0.014233498, -0.001977779, -0.01754119, 0.030758942, -0.0030146888, 0.017384922, -0.0058926423, -0.029925507, 0.010554667, -0.0109127825, 0.010417931, -0.022971537, -0.017554214, 0.0019452231, 0.027112665, 0.016746825, 0.0053912792, -0.012814055, 0.0113295, 0.024130533, -0.0092459135, 0.01500182, -0.0029023704, 0.0063126152, 0.007826471, -1.0567994e-05, 0.004655513, 0.009695187, 0.029092072, -0.009154757, 0.02185161, -0.0006376913, -0.01580921, 0.0052675665, -0.00944125, 0.0039360244, -0.02104422, 0.011414146, 0.035577234, 0.011811329, 0.0058405525, -0.009284981, -0.024625385, -0.01009237, 0.0057884627, -0.030264089, 0.025159303, -0.007090704, -3.860942e-05, 0.009812389, 0.019129926, -0.017020294, -0.02082284, -0.0271908, 0.025146281, 0.0005538595, 0.037218057, 0.005615916, 0.008711995, 0.020796794, -0.011609482, -0.0059707765, -0.018726232, 0.00047898066, 0.0339885, 0.022971537, 0.010535133, -0.68716675, -0.014480924, 0.030290134, 0.022346461, 0.0044373875, 0.016382197, 0.012065266, 0.026774082, -0.0028877202, 0.021643251, -0.014493947, 0.022033924, -0.0009962147, -0.009532407, 0.0034574508, -0.0115704145, 0.008197609, -0.025888558, -0.01106254, 0.02222926, -0.016499398, 0.030029686, -0.018049065, -0.006895368, -0.00188825, 0.0016538466, 0.005137342, -0.020210786, -0.015678987, 0.037738957, -0.019273173, 0.017254699, 0.013491221, -0.0047922484, 0.04823502, 0.020275898, -0.0069083907, 0.0063484265, 0.0153013365, 0.040395528, -0.02212508, -0.026018783, 0.002930043, -0.007240462, 0.011199276, 0.0044699437, -0.00035831984, -0.012905212, -0.011811329, 0.002529604, 0.02724289, -0.008484103, 0.018934589, 0.012501517, 0.0040564816, -0.0026809894, 0.0121434005, 0.0017580258, -0.0005762418, 0.020861907, -0.0019029002, 0.019624777, 0.004668535, 0.0017384923, -0.019025747, 0.013842826, -0.015822232, -0.0031335184, 0.0020721916, -0.016382197, 0.0035193074, 0.0026891285, -0.021395825, -0.018465783, 0.019833136, 0.039796498, 0.008965932, -0.0133740185, -0.0059642657, 0.02703453, 0.022268327, 0.0034965181, -0.013764692, -0.027607517, 0.018309513, -0.027373113, -0.03015991, -0.013842826, -0.003932769, -0.0002750985, 0.036019996, 0.013426108, -0.014572081, -0.034561485, 0.023205942, 0.010841159, -0.013211239, -0.005469414, 0.018218357, -0.00485 ...

# %%
print(db.list_collection_names())
# Out:
# ['products', 'customers', 'sales']

# %% [markdown]
# Vectorize and update all documents in the Cosmic Works database

# %%
def add_collection_content_vector_field(collection_name: str):
    '''
    Add a new field to the collection to hold the vectorized content of each document.
    '''
    collection = db[collection_name]
    bulk_operations = []

    # Check if collection is empty
    if collection.count_documents({}) == 0:
        print(f"The collection '{collection_name}' is empty.")
        return
    

    for doc in collection.find():

        # Remove any previous contentVector embeddings
        if "contentVector" in doc:
            del doc["contentVector"]

        # Generate embeddings for the document string representation
        content = json.dumps(doc, default=str)
        content_vector = generate_embeddings(content)
        
        bulk_operations.append(pymongo.UpdateOne(
            {"_id": doc["_id"]},
            {"$set": {"contentVector": content_vector}},
            upsert=True
        ))

    # Check if bulk_operations is empty
    if not bulk_operations:
        print(f"No operations to execute for collection '{collection_name}'.")
        return

    # Execute bulk operations
    collection.bulk_write(bulk_operations)

# %%
# Add vector field to products documents - this will take approximately 3-5 minutes due to rate limiting
add_collection_content_vector_field("products")
# Out:
# Processing document ID: 027D0B9A-F9D9-4C96-8213-C8546C4AAE71
# Processing document ID: 08225A9E-F2B3-4FA3-AB08-8C70ADD6C3C2
# Processing document ID: 0A7E57DA-C73F-467F-954F-17B7AFD6227E
# Processing document ID: 14174164-F6C0-47FC-83FB-604C6A63408D
# Processing document ID: 1A176FDB-D9A8-4888-BDD9-CE4F12E97AAE
# Processing document ID: 201D0D79-81AD-43D2-AD6E-F09EEE6AC2D7
# Processing document ID: 24BE4267-85D8-4C1A-B184-C08709495752
# Processing document ID: 290B4594-95BE-47C5-863A-4EFAAFC0AED7
# Processing document ID: 29663491-D2E9-47B4-83AE-D9459B6B5B67
# Processing document ID: 2C981511-AC73-4A65-9DA3-A0577E386394
# Processing document ID: 3F105575-8677-42F9-8E1F-76E4B450F136
# Processing document ID: 3FE1A99E-DE14-4D11-B635-F5D39258A0B9
# Processing document ID: 44873725-7B3B-4B28-804D-963D2D62E761
# Processing document ID: 47C70E1E-E500-41B3-8615-DCCB963D9E35
# Processing document ID: 4B0848F8-7BF5-4DB9-84A7-C4D69F2E3E8E
# Processing document ID: 4E4B38CB-0D82-43E5-89AF-20270CD28A04
# Processing document ID: 5089E32E-8A60-4117-AA98-5EF8AB9A61D1
# Processing document ID: 52FAD88C-567E-469D-A35E-574EA3BF147F
# Processing document ID: 5308BAE7-B0CB-4883-9A93-192CB10DC94F
# Processing document ID: 5996B5E0-6EC7-4CB7-A924-7B5A053AE980
# Processing document ID: 5B5E90B8-FEA2-4D6C-B728-EC586656FA6D
# Processing document ID: 5BFADECD-2240-4480-9485-1256D1D60EA8
# Processing document ID: 6E3AA511-67DF-4EAD-8F0C-4C9F91F7D335
# Processing document ID: 6FB5B2D5-5725-4998-9B6C-2FF2B7A3E3E0
# Processing document ID: 71BDFE67-6499-4A8E-9CCA-9E9AF7D92A7A
# Processing document ID: 7BAA49C9-21B5-4EEF-9F6B-BCD6DA7C2239
# Processing document ID: 7EA0EEEB-824E-42E9-B787-019219CE4466
# Processing document ID: 80D3630F-B661-4FD6-A296-CD03BB7A4A0C
# Processing document ID: 866F8033-A439-42D9-99EE-178C1285F13E
# Processing document ID: 906A453F-2B5E-469A-87B5-FFA531EE615D
# Processing document ID: 9190229B-1372-4997-8F64-5B3E7A2459C5
# Processing document ID: 94265B3D-7718-47F0-ADF7-64DEE36CAC41
# Processing document ID: 967155B3-9925-4FA3-84B0-B24CDA101C1B
# Processing document ID: 98324A24-9D56-4662-93A5-9A7370E7EE5A
# Processing document ID: 9851FE19-CCA4-4B94-B6AC-CCE579D7F693
# Processing document ID: 987E39AC-6C62-4717-9929-E9BDFF9902ED
# Processing document ID: 9E6692D7-57E1-4D35-ACD8-105D44A1073B
# Processing document ID: 9FCA9658-8506-4268-8539-DBAA65C51F41
# Processing document ID: A042C88C-B060-4A64-B314-ED92124047E5
# Processing document ID: A13C5B23-34DF-41C7-849C-0BA623BEFE02
# Processing document ID: A6BB4603-7CD5-43DC-920A-2A2F55D52492
# Processing document ID: A875BC33-C4AC-4D2B-B018-9FF4672A2BB9
# Processing document ID: A9EFB9E2-8859-4401-B8A6-F7E2D5264FEE
# Processing document ID: ABB81D0E-4744-44EC-8AAB-FB3962FD2AF7
# Processing document ID: ABDE32DD-FADD-4042-9278-0440B7B2F3E0
# Processing document ID: ACC683CB-6199-416E-AE64-7C10D0C72CF9
# Processing document ID: AFED4FD0-17D1-4CD5-8639-13F15B043EC2
# Processing document ID: B267655B-A7C1-41E3-9682-21730E93FCB5
# Processing document ID: B2AC17CB-A69E-462E-B72A-917CB544FF81
# Processing document ID: B35B87F4-5ADE-4ED4-9469-DF024AC4195D
# Processing document ID: BCD77A3D-9FF1-4CE4-9327-4C2A41BA9F0F
# Processing document ID: BD340F0A-F661-4ED8-B36F-FBA7623605D9
# Processing document ID: BF381234-799A-4B1A-BD4B-B55891CC5907
# Processing document ID: DA96F0D0-84C7-42C3-BE74-FEB39BD60EF5
# Processing document ID: DB89A887-43E3-4D9C-8783-7F034ACD88C0
# Processing document ID: DC8209E8-151E-425C-B7D9-7F082B66E39D
# Processing document ID: DDD64AA0-30DC-4DC1-BCDC-2882A0FD178C
# Processing document ID: DE8C032F-472A-4FFE-A8AE-4C7FFAF06DA8
# Processing document ID: E08E4507-9666-411B-AAC4-519C00596B0A
# Processing document ID: E60D6D23-0151-4B7E-BC56-598B9FEE026B
# Processing document ID: E78CEEF9-A87B-4612-8BD3-4E5DC8AC4700
# Processing document ID: EDCB55C5-4CF5-424F-9083-310F940879FA
# Processing document ID: EF16A6FA-9BE2-4AF9-872A-299A9EA88D5F
# Processing document ID: F07F8C10-4820-4C80-AAE2-1DDEC41E5A29
# Processing document ID: F32990D7-F8E4-4ACD-AA8C-1F03D8299DE7
# Processing document ID: F6628734-A209-46A2-9010-0F19E7D3F3D3
# Processing document ID: F7261436-B748-42D6-A7C9-ACD2B589F0B7
# Processing document ID: FB118699-4C89-493B-B0AB-DA517935773E
# Processing document ID: FC0B659C-C1EF-41F3-AFE2-F87C7F43AD48
# Processing document ID: FCF95DBC-BBAD-467B-9639-FC6E4EC42B4C
# Processing document ID: 0B013EA7-B40E-4996-A494-D1E2840FEAAE
# Processing document ID: 1BEAE2B0-134A-4780-9A7A-5FA17EADD513
# Processing document ID: 21756241-F313-4D34-9914-9B7DAC76F9D6
# Processing document ID: 26E6C049-667F-4463-AF1D-660953231165
# Processing document ID: 2CE4EFA7-5DC6-4D3E-ACB2-B7DDE4518408
# Processing document ID: 311D60FC-9EB9-4194-B594-1E5BD87CCF81
# Processing document ID: 32C5F63D-CF84-457C-9063-0C758CCDACE7
# Processing document ID: 332C8377-F7B5-44C2-8DFC-B374294FD9B2
# Processing document ID: 34C0090C-B299-433B-8D31-42EFCDC5874D
# Processing document ID: 3B52D15D-DF6C-4042-BA15-2EFEA8A2F852
# Processing document ID: 3FA9E0D9-E6E9-429D-9E24-7DAFE9B99A2C
# Processing document ID: 409BC0E0-2B43-4F82-9C36-2E4ABBB7344C
# Processing document ID: 435D4B82-D557-4752-B825-D28767FB32D3
# Processing document ID: 4424AA2A-CC8D-4471-9478-21E91185593C
# Processing document ID: 491834BE-AAA5-419D-B166-77B93F20EBA7
# Processing document ID: 520E3E6B-95F1-4258-9F74-E434848E88B2
# Processing document ID: 5253671B-E50E-4686-9A17-4F51C2B65C0F
# Processing document ID: 56BB7DD2-2421-4671-A527-7373008DD553
# Processing document ID: 58978B2E-D4C6-4D69-A840-D935688F9C2D
# Processing document ID: 58B0F878-2619-4225-B9B1-9C6C4FFF9C17
# Processing document ID: 600DDD58-C9D0-4118-9A69-B7716ED3A303
# Processing document ID: 61B55CE9-DEB4-49B3-AB55-0AAC11EBBBBF
# Processing document ID: 6374995F-9A78-43CD-AE0D-5F6041078140
# Processing document ID: 7133D6F6-C8FD-4AD1-83E8-5622D1746E25
# Processing document ID: 751115E7-BD5E-45C7-932B-E9DDE9D62579
# Processing document ID: 794ACC61-01E9-49BF-B150-1D02EE01D76F
# Processing document ID: 8826E4D4-36FF-42AD-A33F-0E7794215158
# Processing document ID: 894D03FA-1A4A-4FA4-9A0B-C3169EBB5674
# Processing document ID: 8BAA2AFB-CAE5-4A96-ABB2-46EDF9B5680E
# Processing document ID: 8D3DCF87-D1ED-44DD-8DB8-085EB98C8A52
# Processing document ID: 916ACEDC-DCF4-4118-90C6-B9572D30714E
# Processing document ID: 9183E546-A94B-4B7F-845B-A53E0EF5C626
# Processing document ID: 92413209-8DA6-4661-9E11-26B55990BEB2
# Processing document ID: 92DB7ABD-1C8E-458C-8828-9BFD1984B07D
# Processing document ID: 9351199A-B781-482D-80BE-2C11394002E5
# Processing document ID: A2E169C8-0916-4CAD-9C7B-FBAF463D0DB3
# Processing document ID: A6040C40-906B-4A87-9E2C-683A8037A1C3
# Processing document ID: B03973CE-FAAD-4BE2-84FF-5BA5C751B6D0
# Processing document ID: B08450AA-413C-4663-A62D-7291A8ECF1F5
# Processing document ID: B1AAF271-9DFA-4826-91A3-F3B4BFF49B1C
# Processing document ID: B8587D85-224F-4252-9521-A1763D63AEC2
# Processing document ID: BF87ACE3-C52B-44EA-9871-4A6497B3AF9F
# Processing document ID: C310A68D-DBF2-421A-91CA-F09A3B8A1AAA
# Processing document ID: CB038CA5-3728-4B59-B209-22FAB210F58B
# Processing document ID: E223E34D-E0D0-4DFA-AB7D-8E72F94F2202
# Processing document ID: E5A67B5B-B190-45CB-A9E4-BE3F6BD49214
# Processing document ID: EEE4159B-F224-4C02-B578-2F398229592D
# Processing document ID: FE292D83-1F34-4845-A467-7C62AD3C6CBE
# Processing document ID: FFCA3096-199F-41C3-99D1-35BC88D8AC6F
# Processing document ID: 056C459F-DA40-475E-B7BE-B87B6DB39D33
# Processing document ID: 08CF5494-D064-40CF-952B-E33ED9CE9297
# Processing document ID: 0B77351B-8F31-45D2-AECC-85BABD03B24E
# Processing document ID: 0F124781-C991-48A9-ACF2-249771D44029
# Processing document ID: 12DD6F29-6AA2-4C03-8873-19581F97E9CD
# Processing document ID: 16F9DF28-56B4-4185-9B82-B85666BFA3A6
# Processing document ID: 28A865D5-647E-46B5-B309-CA2B2F524E37
# Processing document ID: 2BA4A26C-A8DB-4645-BEB9-F7D42F50262E
# Processing document ID: 2EE56307-0398-465E-A340-1C5FB1C85648
# Processing document ID: 312A464A-1830-4755-8FB2-2ED32DC7FDD6
# Processing document ID: 32B61AF2-53BE-4E36-85D8-A24738769352
# Processing document ID: 397635D8-D71F-47B2-AD68-4ECA6A03F84F
# Processing document ID: 3ADF5B22-B5B2-43CD-9E07-36A187EB9473
# Processing document ID: 462F8EAF-0988-4D32-B809-EB4362AF48D0
# Processing document ID: 47ED1C3B-C205-4507-94EE-3B69A744B261
# Processing document ID: 4DA12D36-495E-4DCA-95B0-F18CAA099779
# Processing document ID: 55594B1E-1E16-4B2E-A16F-983E492321BC
# Processing document ID: 56560B7B-3AC6-4E07-8825-4266A7C98CFE
# Processing document ID: 5BC9F76B-7FE9-4DD9-A672-2C5E802B2672
# Processing document ID: 5C30FF31-CAB7-4A99-8FD6-D610F58AC4BA
# Processing document ID: 5D3F5A52-A8BB-448C-B8CF-39D2FA2BDF3C
# Processing document ID: 5ED1BF5F-6C1F-4EF8-B1A7-B8A8412C9F72
# Processing document ID: 601A5234-644D-4B83-9FDB-326C22C1051D
# Processing document ID: 61246D01-7C38-489E-9F49-A526679B568F
# Processing document ID: 6401B68F-924A-4B2E-AC9E-5660AEA0E848
# Processing document ID: 668E6FCE-03E9-49E7-AC33-1B17FEEF5E60
# Processing document ID: 6EB9F7AC-7FB0-4D8C-8D3F-76A735A3CB9A
# Processing document ID: 6F733A5D-9B66-4718-B69C-627DE4E164BA
# Processing document ID: 824D58CA-ECCA-4E72-965C-66D3A5C0C67C
# Processing document ID: 840E2138-4265-4AC8-8514-AC0B9C98597C
# Processing document ID: 86FD9250-4BD5-42D2-B941-1C1865A6A65E
# Processing document ID: 8B363B8B-378E-402A-9E68-A935302000B8
# Processing document ID: 8B541087-A7F5-43B1-AC9F-EEFB4F4ADAFA
# Processing document ID: 91AA100C-D092-4190-92A7-7C02410F04EA
# Processing document ID: 91D3C273-9E79-4395-B444-6D39BF9B2F4D
# Processing document ID: 935EB2B7-8D50-4E20-B01A-570DBA674AD4
# Processing document ID: 9C0320C4-124B-486A-BA98-B7B82933F324
# Processing document ID: 9DB28F2B-ADC8-40A2-A677-B0AAFC32CAC8
# Processing document ID: A6F069C2-EF85-4B79-9CE2-03833343AD92
# Processing document ID: ACD4ABE3-82D8-4447-B126-2DE03B7DD106
# Processing document ID: AFBE0496-C372-4885-B509-507B93027174
# Processing document ID: B0FE1D0A-CED1-49E8-9ACF-E289A631A4ED
# Processing document ID: B10065F8-543A-49E7-BFE6-3D19B0BE5670
# Processing document ID: B3847F90-FDF3-4529-B7D0-04FE6F94BFB3
# Processing document ID: B79B140D-4369-429B-8F20-E28F3ED7F82A
# Processing document ID: BB21E6EF-104A-420B-B9C5-2084118E5A2F
# Processing document ID: C0FBA4E8-B617-4889-B1A5-091D12783313
# Processing document ID: CC8D2C8C-AB60-48BE-A019-33F633DB07CD
# Processing document ID: CD5FF4D6-7D2D-4BD4-9319-CB38C1939D96
# Processing document ID: CEA9FD38-517E-474B-A5B1-B17BF1753F9C
# Processing document ID: D47E0CC9-28A0-40A5-AB90-BB29BDBB0578
# Processing document ID: DE810086-817F-440C-9FEF-471083B8E4A0
# Processing document ID: DF94F21F-4CDB-4E49-B67B-CAD318A31C4A
# Processing document ID: DFE5521E-40C6-4A58-8E8D-5FC1BE5EC0FE
# Processing document ID: E2CCAF6F-7AB5-4086-86A3-A50B3E6EF101
# Processing document ID: E681778F-8359-468B-98F9-4D325D6C377F
# Processing document ID: E8767BC9-D6BA-47FC-9842-3511468869B6
# Processing document ID: E9FCF7AC-1F45-4857-9E75-BC30A7C7C27B
# Processing document ID: EC65B816-A2A7-4245-B138-43C03F14C514
# Processing document ID: EE40F7FD-AB2C-4589-B54D-BEBACB3B083E
# Processing document ID: EF3F4DC1-5F73-4234-B10E-6608F4DC937A
# Processing document ID: EFD1F33B-94AE-4309-B6E6-F9CCC2B61278
# Processing document ID: F2447558-7C01-442E-A7BC-B6D5D8AE1070
# Processing document ID: F5FB0386-C6AC-40AE-9342-7AFB832233A8
# Processing document ID: FA06B762-D602-4235-8F77-D8AFB0D3D050
# Processing document ID: FADA3DBE-28DC-4FFA-823E-99332AD2EA0C
# Processing document ID: FB9A5084-F2B2-4C3B-9CF9-252873CABFF7
# Processing document ID: FDEF01CB-5067-414F-B0A3-07FF8A4B80DD
# Processing document ID: FE8FFBD3-99AE-4ECF-AA53-D1304D941EC7
# Processing document ID: 063F1A00-8CA1-4DB9-8298-BEAC4B8CC238
# Processing document ID: 06AC4FFF-9F97-429B-BB15-ED929EFF65EE
# Processing document ID: 0846D2C3-7E50-4F68-A6CB-F0DC90FD03D0
# Processing document ID: 0990C3D9-4EC2-4272-ADB6-9481CA12F5F6
# Processing document ID: 0C3D95EB-EE37-44A5-816F-957A98519B03
# Processing document ID: 0D7CB85D-4518-4E02-8E46-9683947BBBC4
# Processing document ID: 0E92DDAC-F969-4F63-8D5E-614AB5199D01
# Processing document ID: 11E6FD95-0FF1-4FE8-9A6B-EC53F614212D
# Processing document ID: 14912B0B-EA77-47B8-8F1C-C8E4BE859D7C
# Processing document ID: 18711AD6-0999-4E74-B2F5-81720A6BA5A2
# Processing document ID: 18B722BF-4742-4F1F-8336-3AB2E76B2908
# Processing document ID: 1E0D3EBA-563D-4DA1-8D6C-FE9C7A63EE2B
# Processing document ID: 209B4171-CB26-4231-8F41-D092F4679BB9
# Processing document ID: 243AE98C-D657-415C-9EF4-D8FA8F8770AA
# Processing document ID: 2595584F-EA4E-4D45-948E-99A17AF8C519
# Processing document ID: 25B35002-7F61-45E3-AA55-80A743C3BC36
# Processing document ID: 26E8185C-782A-4B48-87FA-1E715E3825FB
# Processing document ID: 28A93A52-553C-4755-A2C4-07C1F5BD30F5
# Processing document ID: 295ABC00-9080-479C-9733-A9BE712D7A18
# Processing document ID: 2BBCE73F-9D1D-4BE1-808C-8B174D0DA1A2
# Processing document ID: 2FBE9F71-86EC-4FEB-BBF4-5580FD28E3FD
# Processing document ID: 3933505E-7BD5-458D-84FE-546AA3520A66
# Processing document ID: 39F4BE10-8C68-4E7E-A185-B05BCA543B9F
# Processing document ID: 3A70EDD4-6C8C-44AA-A13D-49D0F6058699
# Processing document ID: 3CE3E061-88E1-4430-BAC7-809B285FC702
# Processing document ID: 3D9B62A3-3CDF-45A2-B64C-8A9890818E2C
# Processing document ID: 3E144819-7455-4362-A4BB-FAD007A90AEF
# Processing document ID: 3F3E4045-AC4D-4D28-99D5-6C9C53F1DEAF
# Processing document ID: 42FDA4EC-96CA-4160-956A-3870549AF76E
# Processing document ID: 4973E28A-A70A-45B9-8517-5D3B647E82C2
# Processing document ID: 49ACE2DB-4315-4C16-819E-BE372922C634
# Processing document ID: 49E5C64F-B689-4C0B-9E2C-5DFF006B929D
# Processing document ID: 4F9FC42A-F43F-4C13-92FC-ADF701F48C36
# Processing document ID: 50DC9B64-03B8-49AB-9DB4-75D12B3180D8
# Processing document ID: 58C93A21-73D1-44D8-ACF1-3A9E1DB0CE0D
# Processing document ID: 5C24E8CD-2BFF-460A-88D4-3A2926407346
# Processing document ID: 626D67C2-C316-49EB-8316-129BDFBFDE8A
# Processing document ID: 637D953B-42DB-4219-927F-51687E889A04
# Processing document ID: 64B3F15E-3E21-4ECD-9013-E50ABD324337
# Processing document ID: 6964ECD2-6FC5-4D65-88BC-126BC2BE2CCB
# Processing document ID: 6AEDC59D-F3E3-4B4F-9290-7EFC225B7F42
# Processing document ID: 6B41F665-5810-4AFD-8323-6106A8593EFC
# Processing document ID: 6E059A32-56B5-4D98-AC6A-945B488B32A1
# Processing document ID: 6EAA3D6B-A290-48C4-B3ED-D668261512CD
# Processing document ID: 707106D2-0687-4217-AD2C-A6B828DFE075
# Processing document ID: 71BC9DC2-A409-4B4A-A34B-FCBF1E596FCF
# Processing document ID: 7236DDB5-CFE0-4D3D-8FE5-799B398396B1
# Processing document ID: 7355D821-E33B-410B-AE64-D5A535F767EB
# Processing document ID: 744A624B-E4C2-429E-8A69-DC3B57682BD5
# Processing document ID: 78E7D28A-2D53-40DC-9ED2-8E2841820DEB
# Processing document ID: 7AD4F00E-BB64-4B02-AC6B-0D5F04B01CAB
# Processing document ID: 7EF2B766-E966-4809-B568-372823002877
# Processing document ID: 829B2717-0D74-43D3-BBD8-27CFDEF5ACA1
# Processing document ID: 878C50F0-7E29-4D0D-A52E-6D8B063673E3
# Processing document ID: 8A4C4A7F-6EE1-4436-89E3-80AA2D8A1154
# Processing document ID: 8B8184BF-B79B-4157-BAA6-D30413BCC7A9
# Processing document ID: 8DB727BC-BE6B-4472-93F9-977B927D0C36
# Processing document ID: 8FE13D26-469C-41FE-BD7E-0A856A82F95C
# Processing document ID: 90888587-BBBD-4632-8A48-5B979586DEE4
# Processing document ID: 91E5405C-DC61-42CE-B900-0F46C94FBBA5
# Processing document ID: 9363838B-2D13-48E8-986D-C9625BE5AB26
# Processing document ID: 93A037C1-7135-4544-A688-3A3A75F25D0E
# Processing document ID: 9E5C74FD-F685-45AE-A799-D67EFB5C28A1
# Processing document ID: 9E5DD0E4-89B5-4300-BD49-87518EE9DB6A
# Processing document ID: 9FEC8F06-D741-42EC-AF1D-E2F83BABC9F5
# Processing document ID: A1D803E1-B9DE-49B4-9E61-66F5C3CD679A
# Processing document ID: A374B506-8D35-456B-8C63-BCE78B5083B8
# Processing document ID: B3217262-876C-4C29-A201-06101B710396
# Processing document ID: B39A06DD-3A51-470E-8253-8D6ACB3EA102
# Processing document ID: B3C8AE66-8E4B-4605-A78D-FF2A8C4EAD9A
# Processing document ID: B6591222-0FB9-415F-8F2B-18B56A483AA1
# Processing document ID: B73FFF5D-37A0-4A29-A42C-D91CD6743593
# Processing document ID: B8E30737-758B-49E0-A153-B210B80749F4
# Processing document ID: BF3E0E82-DCFC-4EA3-A71C-8C9EAA329E14
# Processing document ID: C461038A-6DB6-4EC7-924F-ECA906259A6E
# Processing document ID: C6941C95-C463-4F66-BE5F-8CA9C5F7FD91
# Processing document ID: C7B411C0-31F7-4634-B62F-ED349027EFE0
# Processing document ID: C7BE1762-AC9D-4239-BD15-F3096B08AFA9
# Processing document ID: CAC12FD1-C2ED-4B75-9199-86EB2044DB0D
# Processing document ID: CB1F441C-90E4-4E0B-ABDA-E0D07AFC2E01
# Processing document ID: CDFC37BB-8DB8-4D66-841D-7C3FF28B1F0A
# Processing document ID: CE35E963-F6ED-4108-BC4B-6A3DD0557B47
# Processing document ID: D17F948A-2316-4E2E-8D89-973C92FAD9ED
# Processing document ID: D1F006A3-C6C0-42A4-B479-FC3A510C9E9E
# Processing document ID: D616598D-3159-4616-BF9D-FD316BF07224
# Processing document ID: D8CA2EB2-7532-4F74-9D1D-E8CCC7326604
# Processing document ID: D9FCCC86-10FD-47E9-B68B-F0DFE758AA0E
# Processing document ID: E2FD2420-B084-4764-8BC4-94574DFF1AC6
# Processing document ID: E49AE44E-40AC-4FD8-A007-EEC046F02684
# Processing document ID: E54D5E31-073F-4D37-8400-E63A2994C92C
# Processing document ID: E5C302BB-43AC-4E47-8355-F0D2165C394A
# Processing document ID: E5CEC513-A0F9-4437-B26D-A9FB28237554
# Processing document ID: E9F21624-C055-4D5F-8C02-8F69C1EA0AEE
# Processing document ID: EB793BFC-82A4-4EF4-BB2A-4FD218DD1843
# Processing document ID: EC2ADE30-9132-4DFE-B8FE-D233DDFFAAB3
# Processing document ID: F1AA8B6D-4CF2-4DB2-BB17-997C2BD1A6AC
# Processing document ID: F25B4447-9094-42DB-8244-186A279E461C
# Processing document ID: F3012443-6317-4856-800A-6E108A5F8AE5
# Processing document ID: F42672DA-1B19-463B-B49D-AC4EA2E1F77C
# Processing document ID: F58F50FB-BE83-4AE1-ACF0-662F702B2E5A
# Processing document ID: F59ECC09-CAA5-4D3C-87A7-16945A92EA2D
# Processing document ID: F7078B88-417F-44C0-9345-DCEDDB5C41F8
# Processing document ID: F741B78B-36F0-42E9-A26A-FAE908E0FB3A
# Processing document ID: FD00408C-57B1-431C-B1FA-2CAF41D87CD4
# Processing document ID: FD48A179-6CF5-45F2-8605-9DA19B9D4409
# Processing document ID: FDD4E68A-6284-4DC7-B48D-232F347CA827
# Processing document ID: FEEFEE3B-6CB9-4A75-B896-5182531F661B

# %%
# Add vector field to customers documents - this will take approximately 1-2 minutes due to rate limiting
add_collection_content_vector_field("customers")
# Out:
# Processing document ID: 022BB1FA-35E6-4CC5-9079-8EA61FE7FAAE
# Processing document ID: 0E57A241-1B95-43A2-BCFB-637608B0AD1A
# Processing document ID: 23A65A9A-479C-44D2-9F6A-E6CDA8B0BE08
# Processing document ID: 29C95F8A-9C52-48DB-A1C4-8A14C430FF06
# Processing document ID: 34E7A125-0F66-4673-A80B-20B4C46EAD3A
# Processing document ID: 35D52474-3D1A-433C-A310-10FA7DF8950B
# Processing document ID: 3945DB3E-2632-466C-BCBE-0C252729C937
# Processing document ID: 44A6D5F6-AF44-4B34-8AB5-21C5DC50926E
# Processing document ID: 45E422FD-0AE2-4C73-8883-61B1C3BB4431
# Processing document ID: 4FEAA310-61D4-4A89-8E78-3CA6B34F7934
# Processing document ID: 537E369C-C65B-4F23-B7C0-D07DFFFAC08B
# Processing document ID: 5EE9C404-EBE5-45F6-8063-E537AA5E750C
# Processing document ID: 6325847B-D85C-4F23-9C47-7346082D38A1
# Processing document ID: 670C1D45-DCAF-4B08-8358-F1DFBAE8E8C8
# Processing document ID: 6A0B9894-8EDB-4568-A4AC-03241F72F62C
# Processing document ID: 6DF10977-EA10-4607-AF0F-74EDABA54943
# Processing document ID: 72F4BF6F-6BF5-4E22-89C1-29505FD74710
# Processing document ID: 7688FC05-6780-428D-AFD9-0F0639EA7148
# Processing document ID: 8B0C1168-28E6-4F0D-82FB-C53123F76280
# Processing document ID: 8D2B7802-AC71-4C20-8462-BF9157600C36
# Processing document ID: 9092EEDE-9BE8-4E85-B017-A243C291173E
# Processing document ID: 91A01FF7-B425-4A9F-B2F4-E4285E1D78AE
# Processing document ID: C13244AB-0B74-4466-985D-BA1C1731968C
# Processing document ID: D01E483D-AEE0-41E6-A2E1-0220AA233A7A
# Processing document ID: D133397E-83ED-4FF3-BD44-62D7481237B2
# Processing document ID: D6A5D690-7A0C-42F4-8557-B1FE8326795F
# Processing document ID: DA80C3E9-0130-4A0E-B209-55DDB675D2A1
# Processing document ID: E2094914-6C88-44CC-B5F4-AA4FB78C2710
# Processing document ID: E36CB859-8D01-42AE-A28F-5EBAC8C4B918
# Processing document ID: ED0B129D-4B38-4E1F-B404-18FA2B68944D
# Processing document ID: ED5B6EC1-79B6-4902-B325-F9A900854022
# Processing document ID: F5E9C71A-DA28-4F43-9512-825C3AD94528
# Processing document ID: 16709E18-9C25-499B-8A7A-01BB3BA817B9
# Processing document ID: 5A0685C2-34EE-43BA-B127-91A03A848E4B
# Processing document ID: 646D5AF3-2964-41FD-BF53-53D02D4D10DC
# Processing document ID: 6B6963EF-B85A-4562-A5A7-69D06484B39C
# Processing document ID: 78D2838F-3B52-449B-86E9-BE2616E71477
# Processing document ID: 8AB187E0-E5DD-4946-8E9B-00104F697E34
# Processing document ID: A0449CF6-877C-4C3C-AA23-7C09E66A5DF7
# Processing document ID: A5A027A9-3E06-4E60-B079-E833F9C9E224
# Processing document ID: B9A33305-1565-43ED-8804-2F0CB5A908CA
# Processing document ID: C3E223E7-2593-4077-8251-148B28E8BAB8
# Processing document ID: CB39DA0E-99F9-4141-8A8C-FF88E3BC6B15
# Processing document ID: CD903136-EDE6-461C-8E15-62A1083D4372
# Processing document ID: E69F4F80-1002-49A2-9E5A-ADBA4B8C318D
# Processing document ID: E817926F-83D6-4F6D-BC1B-EAE2BF335E08
# Processing document ID: EE85A929-32B2-46F7-9B5F-FE99424465ED
# Processing document ID: 1DD4A19A-8403-4699-B237-77FDBFE1C023
# Processing document ID: 2E197257-A77F-497C-A3AD-7A06C6ECB310
# Processing document ID: 359AB28A-9D88-4776-915D-6F401229438B
# Processing document ID: 436BC51C-D993-4D81-81C1-FF7EEA7F30CB
# Processing document ID: 505006DB-9234-4AD1-A0E5-8A3A068009D5
# Processing document ID: 52FCCDBE-7CA9-4D98-880A-BC6133A8FE4E
# Processing document ID: 5417139A-BD6F-4B66-95D3-35E142128C29
# Processing document ID: 5D7008BF-206A-487A-A38C-7578028408DC
# Processing document ID: 6666BD72-174A-485D-99DD-91FD5DA880AD
# Processing document ID: 6BECEBE9-FACB-417C-915D-EA00C013DF48
# Processing document ID: 77A64329-1C2A-4BE4-867C-56B40962EC4E
# Processing document ID: 77CAC3DB-5B66-45D2-8999-5689D4617CC1
# Processing document ID: 7E4AFF5C-72AA-4337-A20B-EF42FB3344A7
# Processing document ID: AA7014E5-84AB-4A1C-B0D3-A0DD445B90FC
# Processing document ID: B0241DAE-564E-4315-A0FA-D516BD2342DE
# Processing document ID: B127D1E2-A59C-46AF-BC88-C6D0A042AFDF
# Processing document ID: B5A44B86-BF45-4522-BF4A-CEACDBA64AA8
# Processing document ID: BBD2C880-3E22-4851-BD52-CABE05C5C44F
# Processing document ID: D15FD675-46AB-40AE-AA9E-43CC6A2E52F2
# Processing document ID: D19E2E0E-AD57-415F-A0D4-64BB29B06B53
# Processing document ID: D73BFD5B-4729-43E2-9003-4C42B62540F7
# Processing document ID: DF08F654-EF9E-416E-9768-79EF6245CD58
# Processing document ID: E92BE3FC-736B-41F1-B330-0F5FFF761E85
# Processing document ID: EF4C6521-5CE5-44BE-B290-96D3DA1EC22B
# Processing document ID: F2F277E2-0C40-4DA8-87CA-988797AE7F23
# Processing document ID: 0B09489D-7231-49B9-8451-571882260C69
# Processing document ID: 0C7DED8E-6C3A-4AE1-922E-61B4D242F3EA
# Processing document ID: 13584ECC-D5FE-4142-A637-E6F9B733CD18
# Processing document ID: 23981BC6-E156-4543-890E-52289D4DD76B
# Processing document ID: 2E58D6BE-F411-4833-92D4-F074D9FC075E
# Processing document ID: 359B3E2D-416C-40F6-A458-3C11EB73460B
# Processing document ID: 3CB05820-3F7D-42D7-B1C2-51A60E6717F5
# Processing document ID: 4A029345-BF49-4EEB-885A-1B2E0EA5A059
# Processing document ID: 4E7FA9A6-F934-4D67-BC68-6CDD0F28A25D
# Processing document ID: 50CA47E7-DD4C-4002-BB10-CF2118B9E1A9
# Processing document ID: 52AAF997-D288-4617-9784-FD264D06AB6F
# Processing document ID: 5A95DE75-1E03-43C6-AA7F-45A72904F396
# Processing document ID: 5B895F01-96AE-46E0-9D76-18D02EB79E5D
# Processing document ID: 5C501F15-F24D-45BF-B046-84C6234F2694
# Processing document ID: 6298D7A2-9E0A-4209-B360-CE06877FAA3D
# Processing document ID: 64B7B145-43AD-4B85-B7CD-571F10879336
# Processing document ID: 67611460-BC4E-4029-B2A3-67C1DCA26555
# Processing document ID: 69A9D56E-1300-4985-AEA2-D5BFDF0B2FC2
# Processing document ID: 80DAF156-6E8C-406F-9178-33315B4A8D03
# Processing document ID: 8142537D-7232-4F3E-AC3B-3E6F0AC8C940
# Processing document ID: 81D05FA5-48BB-489A-AECB-EB8A43A0C7B4
# Processing document ID: 84A4F0F6-4F7F-40E2-AC2F-400251388551
# Processing document ID: 8FDD739A-81CB-45D0-96EB-3AFD77E60348
# Processing document ID: 9A8F3038-F783-4B6C-9CC4-8B22575955D6
# Processing document ID: B3C3867F-9886-46F4-ADC7-CFF87DA89588
# Processing document ID: B65DF47B-2BE9-44C5-94EF-B62FCB702DCE
# Processing document ID: C411C25C-CD3E-419E-A241-E90B15A286B4
# Processing document ID: CC16EA54-99FB-4BCD-82D7-F1B061E820EE

# %%
# Add vector field to sales documents - this will take approximately 15-20 minutes due to rate limiting
add_collection_content_vector_field("sales")

# %%
# Create the products vector index
db.command({
  'createIndexes': 'products',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})

# Create the customers vector index
db.command({
  'createIndexes': 'customers',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})

# Create the sales vector index
db.command({
  'createIndexes': 'sales',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "contentVector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 1,
#    'numIndexesAfter': 2,
#    'createdCollectionAutomatically': False,
#    'ok': 1}},
#  'ok': 1}

# %% [markdown]
# Use vector search in vCore-based Azure Cosmos DB for MongoDB
#
# Now that each document has its associated vector embedding and the vector indexes have been created on each collection, we can now use the vector search capabilities of vCore-based Azure Cosmos DB for MongoDB.

# %%
def vector_search(collection_name, query, num_results=3):
    """
    Perform a vector search on the specified collection by vectorizing
    the query and searching the vector index for the most similar documents.

    returns a list of the top num_results most similar documents
    """
    collection = db[collection_name]
    query_embedding = generate_embeddings(query)    
    pipeline = [
        {
            '$search': {
                "cosmosSearch": {
                    "vector": query_embedding,
                    "path": "contentVector",
                    "k": num_results
                },
                "returnStoredSource": True }},
        {'$project': { 'similarityScore': { '$meta': 'searchScore' }, 'document' : '$$ROOT' } }
    ]
    results = collection.aggregate(pipeline)
    return results

def print_product_search_result(result):
    '''
    Print the search result document in a readable format
    '''
    print(f"Similarity Score: {result['similarityScore']}")  
    print(f"Name: {result['document']['name']}")   
    print(f"Category: {result['document']['categoryName']}")
    print(f"SKU: {result['document']['categoryName']}")
    print(f"_id: {result['document']['_id']}\n")

# %%
query = "What bikes do you have?"
results = vector_search("products", query, num_results=4)
for result in results:
    print_product_search_result(result)
# Out:
# Similarity Score: 0.7668056488037109
# Name: Road-750 Black, 48
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 2595584F-EA4E-4D45-948E-99A17AF8C519
#
# Similarity Score: 0.7646317937750707
# Name: Road-550-W Yellow, 40
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 3A70EDD4-6C8C-44AA-A13D-49D0F6058699
#
# Similarity Score: 0.764350845554422
# Name: Mountain-300 Black, 48
# Category: Bikes, Mountain Bikes
# SKU: Bikes, Mountain Bikes
# _id: E8767BC9-D6BA-47FC-9842-3511468869B6
#
# Similarity Score: 0.7631214229771299
# Name: Road-550-W Yellow, 48
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 26E8185C-782A-4B48-87FA-1E715E3825FB

# %%
query = "What do you have that is yellow?"
results = vector_search("products", query, num_results=4)
for result in results:
    print_product_search_result(result)
# Out:
# Similarity Score: 0.7417972924536421
# Name: Road-550-W Yellow, 48
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 26E8185C-782A-4B48-87FA-1E715E3825FB
#
# Similarity Score: 0.7403228217074814
# Name: Road-350-W Yellow, 40
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 9E5C74FD-F685-45AE-A799-D67EFB5C28A1
#
# Similarity Score: 0.7373172703967041
# Name: Road-550-W Yellow, 40
# Category: Bikes, Road Bikes
# SKU: Bikes, Road Bikes
# _id: 3A70EDD4-6C8C-44AA-A13D-49D0F6058699
#
# Similarity Score: 0.7355404996187269
# Name: LL Touring Frame - Yellow, 62
# Category: Components, Touring Frames
# SKU: Components, Touring Frames
# _id: 91AA100C-D092-4190-92A7-7C02410F04EA

# %%
query = "What type of products you have?"
results = vector_search("products", query, num_results=4)
for result in results:
    print_product_search_result(result)
# Out:
# Similarity Score: 0.7479221743229322
# Name: HL Fork
# Category: Components, Forks
# SKU: Components, Forks
# _id: 751115E7-BD5E-45C7-932B-E9DDE9D62579
#
# Similarity Score: 0.7470571398735258
# Name: LL Headset
# Category: Components, Headsets
# SKU: Components, Headsets
# _id: FC0B659C-C1EF-41F3-AFE2-F87C7F43AD48
#
# Similarity Score: 0.7468865362934313
# Name: Mountain Pump
# Category: Accessories, Pumps
# SKU: Accessories, Pumps
# _id: FE292D83-1F34-4845-A467-7C62AD3C6CBE
#
# Similarity Score: 0.7463898952472138
# Name: HL Mountain Frame - Black, 38
# Category: Components, Mountain Frames
# SKU: Components, Mountain Frames
# _id: 0990C3D9-4EC2-4272-ADB6-9481CA12F5F6

# %%
query = "What do you have that is yellow?"
results = vector_search("products", query, num_results=4)
for result in results:
    print_product_search_result(result)

# %% [markdown]
# Use vector search results in a RAG pattern with Chat GPT-3.5

# %%
# A system prompt describes the responsibilities, instructions, and persona of the AI.
system_prompt = """
You are a helpful, fun and friendly sales assistant for Cosmic Works, a bicycle and bicycle accessories store. 
Your name is Cosmo.
You are designed to answer questions about the products that Cosmic Works sells.

Only answer questions related to the information provided in the list of products below that are represented
in JSON format.

If you are asked a question that is not in the list, respond with "I don't know."

List of products:
"""

# %%
def rag_with_vector_search(question: str, num_results: int = 3):
    """
    Use the RAG model to generate a prompt using vector search results based on the
    incoming question.  
    """
    # perform the vector search and build product list
    results = vector_search("products", question, num_results=num_results)
    product_list = ""
    for result in results:
        if "contentVector" in result["document"]:
            del result["document"]["contentVector"]
        product_list += json.dumps(result["document"], indent=4, default=str) + "\n\n"

    # generate prompt for the LLM with vector results
    formatted_prompt = system_prompt + product_list

    # prepare the LLM request
    messages = [
        {"role": "system", "content": formatted_prompt},
        {"role": "user", "content": question}
    ]

    completion = ai_client.chat.completions.create(messages=messages, model=COMPLETIONS_DEPLOYMENT_NAME)
    return completion.choices[0].message.content

# %%
print(rag_with_vector_search("What bikes do you have?", 5))
# Out:
# We have the following bikes available:
# 1. Road-750 Black, 48
# 2. Road-550-W Yellow, 40
# 3. Mountain-300 Black, 48
# 4. Road-550-W Yellow, 48
# 5. Touring-1000 Yellow, 60

# %%
print(rag_with_vector_search("What are the names and skus of yellow products?", 5))
# Out:
# The names and skus of yellow products are as follows:
#
# 1. Road-550-W Yellow, 48 (SKU: BK-R64Y-48)
# 2. ML Road Frame-W - Yellow, 48 (SKU: FR-R72Y-48)
# 3. Road-550-W Yellow, 40 (SKU: BK-R64Y-40)
# 4. Road-350-W Yellow, 48 (SKU: BK-R79Y-48)
# 5. Touring-1000 Yellow, 60 (SKU: BK-T79Y-60)

# %%
print(rag_with_vector_search("What are the diferent types of products you have?", 10))
# Out:
# The different types of products we have are Components, Forks (HL Fork, LL Fork), Components, Headsets (LL Headset), Accessories, Cleaners (Bike Wash - Dissolver), Accessories, Pumps (Mountain Pump), Accessories, Lights (Headlights - Dual-Beam), Components, Derailleurs (Front Derailleur), Components, Mountain Frames (HL Mountain Frame - Black, 38), Components, Chains (Chain), and Components, Road Frames (ML Road Frame-W - Yellow, 48).
